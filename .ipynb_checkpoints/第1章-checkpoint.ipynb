# %% [markdown]
# ## 1.4  使用matplotlib绘制图表

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (1.24.4)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (3.7.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/datavis/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.array([1, 2, 3, 4, 5])        # 准备数据
fig = plt.figure()                      #  创建代表画布的Figure 类的对象fig
ax = fig.add_subplot(223)               # 在画布fig上添加坐标系风格的绘图区域ax
ax.plot(data)                           #  绘制图表
plt.show()                              #  展示图表

# %%
import numpy as np
import matplotlib.pyplot as plt     # 导入 pyplot 模块
data = np.array([1, 2, 3, 4, 5])     # 准备数据
plt.plot(data)                       # 在当前画布的绘图区域中绘制图表
plt.show()                           # 展示图表
